# %%
import gymnasium as gym
import torch
import time
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
import ale_py

from wrapper.wrapper import PongWrapper

gym.register_envs(ale_py)

ENV_NAME = "PongNoFrameskip-v4"
TOTAL_TIMESTEPS = 3_000_000
MODEL_PATH = "ppo_pong"

def train():
    env = make_atari_env(ENV_NAME, n_envs=1, seed=0)
    env.envs[0] = PongWrapper(env.envs[0], buffer_stack_size=3)  # manually wrap base env
    env = VecFrameStack(env, n_stack=4)

    # model = PPO("CnnPolicy", env, verbose=1)
    model = PPO.load(MODEL_PATH, env=env)

    model.learn(total_timesteps=TOTAL_TIMESTEPS)
    model.save(MODEL_PATH)
    env.close()

def play():
    model = PPO.load(MODEL_PATH)
    env = make_atari_env(ENV_NAME, n_envs=1, seed=0)
    env.envs[0] = PongWrapper(env.envs[0], buffer_stack_size=10)  # manually wrap base env
    env = VecFrameStack(env, n_stack=4)

    obs = env.reset()
    env.render("human")

    while True:
        action, _states = model.predict(obs, deterministic=False)
        obs, rewards, dones, info = env.step(action)
        env.render("human")
        time.sleep(0.01)

    env.close()

# %%
train()
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.0+dfae0bd)
# [Powered by Stella]
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 8.51e+03 |
# |    ep_rew_mean     | -10      |
# | time/              |          |
# |    fps             | 500      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.47e+03   |
# |    ep_rew_mean          | -8.4       |
# | time/                   |            |
# |    fps                  | 438        |
# |    iterations           | 2          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.30298677 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.314     |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0648    |
# |    n_updates            | 9790       |
# |    policy_gradient_loss | -0.0433    |
# |    value_loss           | 0.0601     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.01e+03   |
# |    ep_rew_mean          | -5.38      |
# | time/                   |            |
# |    fps                  | 428        |
# |    iterations           | 3          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.42115867 |
# |    clip_fraction        | 0.447      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.511     |
# |    explained_variance   | 0.726      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0801    |
# |    n_updates            | 9800       |
# |    policy_gradient_loss | -0.0714    |
# |    value_loss           | 0.089      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 8.84e+03 |
# |    ep_rew_mean          | -6.45    |
# | time/                   |          |
# |    fps                  | 425      |
# |    iterations           | 4        |
# |    time_elapsed         | 19       |
# |    total_timesteps      | 8192     |
# | train/                  |          |
# |    approx_kl            | 0.380314 |
# |    clip_fraction        | 0.316    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.321   |
# |    explained_variance   | 0.837    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0574  |
# |    n_updates            | 9810     |
# |    policy_gradient_loss | -0.0556  |
# |    value_loss           | 0.0531   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 9.13e+03  |
# |    ep_rew_mean          | -4.92     |
# | time/                   |           |
# |    fps                  | 421       |
# |    iterations           | 5         |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.3739764 |
# |    clip_fraction        | 0.381     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.401    |
# |    explained_variance   | 0.85      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.076    |
# |    n_updates            | 9820      |
# |    policy_gradient_loss | -0.0618   |
# |    value_loss           | 0.0721    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.61e+03   |
# |    ep_rew_mean          | -7.29      |
# | time/                   |            |
# |    fps                  | 418        |
# |    iterations           | 6          |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.37646112 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.279     |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0449    |
# |    n_updates            | 9830       |
# |    policy_gradient_loss | -0.0443    |
# |    value_loss           | 0.0605     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.59e+03   |
# |    ep_rew_mean          | -7.84      |
# | time/                   |            |
# |    fps                  | 416        |
# |    iterations           | 7          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.51732737 |
# |    clip_fraction        | 0.427      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.462     |
# |    explained_variance   | 0.622      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.065     |
# |    n_updates            | 9840       |
# |    policy_gradient_loss | -0.0732    |
# |    value_loss           | 0.0822     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 8.7e+03   |
# |    ep_rew_mean          | -7.91     |
# | time/                   |           |
# |    fps                  | 415       |
# |    iterations           | 8         |
# |    time_elapsed         | 39        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.5064111 |
# |    clip_fraction        | 0.406     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.418    |
# |    explained_variance   | 0.726     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0645   |
# |    n_updates            | 9850      |
# |    policy_gradient_loss | -0.0679   |
# |    value_loss           | 0.0768    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.83e+03   |
# |    ep_rew_mean          | -7.71      |
# | time/                   |            |
# |    fps                  | 414        |
# |    iterations           | 9          |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.49880368 |
# |    clip_fraction        | 0.419      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.444     |
# |    explained_variance   | 0.714      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0761    |
# |    n_updates            | 9860       |
# |    policy_gradient_loss | -0.0646    |
# |    value_loss           | 0.0758     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.02e+03   |
# |    ep_rew_mean          | -6.11      |
# | time/                   |            |
# |    fps                  | 414        |
# |    iterations           | 10         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.44971395 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.351     |
# |    explained_variance   | 0.801      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0531    |
# |    n_updates            | 9870       |
# |    policy_gradient_loss | -0.0548    |
# |    value_loss           | 0.0834     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.99e+03   |
# |    ep_rew_mean          | -6.17      |
# | time/                   |            |
# |    fps                  | 413        |
# |    iterations           | 11         |
# |    time_elapsed         | 54         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.49385607 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.279     |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0482    |
# |    n_updates            | 9880       |
# |    policy_gradient_loss | -0.0455    |
# |    value_loss           | 0.0375     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9e+03      |
# |    ep_rew_mean          | -6.32      |
# | time/                   |            |
# |    fps                  | 411        |
# |    iterations           | 12         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.34729117 |
# |    clip_fraction        | 0.382      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.404     |
# |    explained_variance   | 0.845      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.073     |
# |    n_updates            | 9890       |
# |    policy_gradient_loss | -0.0682    |
# |    value_loss           | 0.0589     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.63e+03   |
# |    ep_rew_mean          | -6.21      |
# | time/                   |            |
# |    fps                  | 410        |
# |    iterations           | 13         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.37599698 |
# |    clip_fraction        | 0.349      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.367     |
# |    explained_variance   | 0.709      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0727    |
# |    n_updates            | 9900       |
# |    policy_gradient_loss | -0.0431    |
# |    value_loss           | 0.0233     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 9.51e+03  |
# |    ep_rew_mean          | -6.78     |
# | time/                   |           |
# |    fps                  | 409       |
# |    iterations           | 14        |
# |    time_elapsed         | 70        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.4435782 |
# |    clip_fraction        | 0.381     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.384    |
# |    explained_variance   | 0.88      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0638   |
# |    n_updates            | 9910      |
# |    policy_gradient_loss | -0.0657   |
# |    value_loss           | 0.0403    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.45e+03   |
# |    ep_rew_mean          | -6.72      |
# | time/                   |            |
# |    fps                  | 408        |
# |    iterations           | 15         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.37063396 |
# |    clip_fraction        | 0.459      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.51      |
# |    explained_variance   | 0.713      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0985    |
# |    n_updates            | 9920       |
# |    policy_gradient_loss | -0.0783    |
# |    value_loss           | 0.076      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.41e+03   |
# |    ep_rew_mean          | -6.63      |
# | time/                   |            |
# |    fps                  | 408        |
# |    iterations           | 16         |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.48692214 |
# |    clip_fraction        | 0.38       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.392     |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.102     |
# |    n_updates            | 9930       |
# |    policy_gradient_loss | -0.0638    |
# |    value_loss           | 0.0703     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 9.39e+03  |
# |    ep_rew_mean          | -6.84     |
# | time/                   |           |
# |    fps                  | 408       |
# |    iterations           | 17        |
# |    time_elapsed         | 85        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.4557393 |
# |    clip_fraction        | 0.384     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.38     |
# |    explained_variance   | 0.87      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0625   |
# |    n_updates            | 9940      |
# |    policy_gradient_loss | -0.0641   |
# |    value_loss           | 0.0728    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.39e+03   |
# |    ep_rew_mean          | -6.84      |
# | time/                   |            |
# |    fps                  | 407        |
# |    iterations           | 18         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.37034118 |
# |    clip_fraction        | 0.389      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.415     |
# |    explained_variance   | 0.653      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0803    |
# |    n_updates            | 9950       |
# |    policy_gradient_loss | -0.0486    |
# |    value_loss           | 0.0447     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.01e+04   |
# |    ep_rew_mean          | -7.11      |
# | time/                   |            |
# |    fps                  | 407        |
# |    iterations           | 19         |
# |    time_elapsed         | 95         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.23240128 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.369     |
# |    explained_variance   | -5.16      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.063     |
# |    n_updates            | 9960       |
# |    policy_gradient_loss | -0.0105    |
# |    value_loss           | 0.00386    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.96e+03   |
# |    ep_rew_mean          | -7.22      |
# | time/                   |            |
# |    fps                  | 407        |
# |    iterations           | 20         |
# |    time_elapsed         | 100        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.39053744 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.49      |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0815    |
# |    n_updates            | 9970       |
# |    policy_gradient_loss | -0.0718    |
# |    value_loss           | 0.0952     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.74e+03   |
# |    ep_rew_mean          | -7.77      |
# | time/                   |            |
# |    fps                  | 408        |
# |    iterations           | 21         |
# |    time_elapsed         | 105        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.42347282 |
# |    clip_fraction        | 0.385      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.41      |
# |    explained_variance   | 0.849      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0724    |
# |    n_updates            | 9980       |
# |    policy_gradient_loss | -0.063     |
# |    value_loss           | 0.0656     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.8e+03    |
# |    ep_rew_mean          | -7.33      |
# | time/                   |            |
# |    fps                  | 408        |
# |    iterations           | 22         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.37263656 |
# |    clip_fraction        | 0.46       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.541     |
# |    explained_variance   | 0.797      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.064     |
# |    n_updates            | 9990       |
# |    policy_gradient_loss | -0.0808    |
# |    value_loss           | 0.0872     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.78e+03   |
# |    ep_rew_mean          | -7.23      |
# | time/                   |            |
# |    fps                  | 383        |
# |    iterations           | 23         |
# |    time_elapsed         | 122        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.49395388 |
# |    clip_fraction        | 0.343      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.312     |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0937    |
# |    n_updates            | 10000      |
# |    policy_gradient_loss | -0.0511    |
# |    value_loss           | 0.0483     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.83e+03   |
# |    ep_rew_mean          | -7.03      |
# | time/                   |            |
# |    fps                  | 352        |
# |    iterations           | 24         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.35180247 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.333     |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0655    |
# |    n_updates            | 10010      |
# |    policy_gradient_loss | -0.0514    |
# |    value_loss           | 0.043      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.96e+03   |
# |    ep_rew_mean          | -7.1       |
# | time/                   |            |
# |    fps                  | 326        |
# |    iterations           | 25         |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.41884974 |
# |    clip_fraction        | 0.384      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.39      |
# |    explained_variance   | 0.772      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0965    |
# |    n_updates            | 10020      |
# |    policy_gradient_loss | -0.0671    |
# |    value_loss           | 0.0614     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.89e+03   |
# |    ep_rew_mean          | -7.16      |
# | time/                   |            |
# |    fps                  | 318        |
# |    iterations           | 26         |
# |    time_elapsed         | 167        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.49336326 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.311     |
# |    explained_variance   | 0.573      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0717    |
# |    n_updates            | 10030      |
# |    policy_gradient_loss | -0.0459    |
# |    value_loss           | 0.0685     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.9e+03    |
# |    ep_rew_mean          | -6.97      |
# | time/                   |            |
# |    fps                  | 318        |
# |    iterations           | 27         |
# |    time_elapsed         | 173        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.41097814 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.408     |
# |    explained_variance   | 0.699      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.082     |
# |    n_updates            | 10040      |
# |    policy_gradient_loss | -0.0608    |
# |    value_loss           | 0.0757     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.9e+03    |
# |    ep_rew_mean          | -6.97      |
# | time/                   |            |
# |    fps                  | 316        |
# |    iterations           | 28         |
# |    time_elapsed         | 181        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.42735058 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.265     |
# |    explained_variance   | 0.857      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0457    |
# |    n_updates            | 10050      |
# |    policy_gradient_loss | -0.0477    |
# |    value_loss           | 0.0402     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.02e+04  |
# |    ep_rew_mean          | -7.22     |
# | time/                   |           |
# |    fps                  | 314       |
# |    iterations           | 29        |
# |    time_elapsed         | 188       |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.2880631 |
# |    clip_fraction        | 0.232     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.227    |
# |    explained_variance   | 0.708     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0622   |
# |    n_updates            | 10060     |
# |    policy_gradient_loss | -0.0492   |
# |    value_loss           | 0.0214    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.02e+04  |
# |    ep_rew_mean          | -7.11     |
# | time/                   |           |
# |    fps                  | 313       |
# |    iterations           | 30        |
# |    time_elapsed         | 196       |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.4512729 |
# |    clip_fraction        | 0.441     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.523    |
# |    explained_variance   | 0.696     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0825   |
# |    n_updates            | 10070     |
# |    policy_gradient_loss | -0.0764   |
# |    value_loss           | 0.0792    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.01e+04   |
# |    ep_rew_mean          | -7.33      |
# | time/                   |            |
# |    fps                  | 312        |
# |    iterations           | 31         |
# |    time_elapsed         | 203        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.42816454 |
# |    clip_fraction        | 0.374      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.386     |
# |    explained_variance   | 0.814      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0525    |
# |    n_updates            | 10080      |
# |    policy_gradient_loss | -0.0617    |
# |    value_loss           | 0.0558     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.97e+03   |
# |    ep_rew_mean          | -7.53      |
# | time/                   |            |
# |    fps                  | 310        |
# |    iterations           | 32         |
# |    time_elapsed         | 210        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.48701343 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.468     |
# |    explained_variance   | 0.711      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0815    |
# |    n_updates            | 10090      |
# |    policy_gradient_loss | -0.069     |
# |    value_loss           | 0.0917     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.91e+03   |
# |    ep_rew_mean          | -7.67      |
# | time/                   |            |
# |    fps                  | 309        |
# |    iterations           | 33         |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.41708514 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.459     |
# |    explained_variance   | 0.534      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0788    |
# |    n_updates            | 10100      |
# |    policy_gradient_loss | -0.0631    |
# |    value_loss           | 0.103      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.93e+03   |
# |    ep_rew_mean          | -7.83      |
# | time/                   |            |
# |    fps                  | 308        |
# |    iterations           | 34         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.48873746 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.437     |
# |    explained_variance   | 0.73       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0731    |
# |    n_updates            | 10110      |
# |    policy_gradient_loss | -0.0705    |
# |    value_loss           | 0.0766     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.94e+03   |
# |    ep_rew_mean          | -7.69      |
# | time/                   |            |
# |    fps                  | 307        |
# |    iterations           | 35         |
# |    time_elapsed         | 232        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.40787107 |
# |    clip_fraction        | 0.354      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.366     |
# |    explained_variance   | 0.748      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0618    |
# |    n_updates            | 10120      |
# |    policy_gradient_loss | -0.0593    |
# |    value_loss           | 0.0781     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.95e+03   |
# |    ep_rew_mean          | -7.7       |
# | time/                   |            |
# |    fps                  | 306        |
# |    iterations           | 36         |
# |    time_elapsed         | 240        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.48197377 |
# |    clip_fraction        | 0.374      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.363     |
# |    explained_variance   | 0.786      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0561    |
# |    n_updates            | 10130      |
# |    policy_gradient_loss | -0.0632    |
# |    value_loss           | 0.0615     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.88e+03   |
# |    ep_rew_mean          | -7.84      |
# | time/                   |            |
# |    fps                  | 306        |
# |    iterations           | 37         |
# |    time_elapsed         | 247        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.41803497 |
# |    clip_fraction        | 0.386      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.371     |
# |    explained_variance   | 0.683      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.083     |
# |    n_updates            | 10140      |
# |    policy_gradient_loss | -0.0636    |
# |    value_loss           | 0.0717     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.86e+03   |
# |    ep_rew_mean          | -7.9       |
# | time/                   |            |
# |    fps                  | 305        |
# |    iterations           | 38         |
# |    time_elapsed         | 254        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.49238068 |
# |    clip_fraction        | 0.382      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.411     |
# |    explained_variance   | 0.747      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0403    |
# |    n_updates            | 10150      |
# |    policy_gradient_loss | -0.0661    |
# |    value_loss           | 0.129      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 9.83e+03 |
# |    ep_rew_mean          | -7.85    |
# | time/                   |          |
# |    fps                  | 304      |
# |    iterations           | 39       |
# |    time_elapsed         | 262      |
# |    total_timesteps      | 79872    |
# | train/                  |          |
# |    approx_kl            | 0.50156  |
# |    clip_fraction        | 0.356    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.335   |
# |    explained_variance   | 0.748    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0675  |
# |    n_updates            | 10160    |
# |    policy_gradient_loss | -0.0591  |
# |    value_loss           | 0.0706   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.84e+03   |
# |    ep_rew_mean          | -7.71      |
# | time/                   |            |
# |    fps                  | 303        |
# |    iterations           | 40         |
# |    time_elapsed         | 269        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.47279143 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.345     |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0701    |
# |    n_updates            | 10170      |
# |    policy_gradient_loss | -0.0578    |
# |    value_loss           | 0.0725     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.89e+03   |
# |    ep_rew_mean          | -7.52      |
# | time/                   |            |
# |    fps                  | 303        |
# |    iterations           | 41         |
# |    time_elapsed         | 276        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.44426703 |
# |    clip_fraction        | 0.311      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.271     |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.069     |
# |    n_updates            | 10180      |
# |    policy_gradient_loss | -0.0507    |
# |    value_loss           | 0.0454     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.89e+03   |
# |    ep_rew_mean          | -7.52      |
# | time/                   |            |
# |    fps                  | 302        |
# |    iterations           | 42         |
# |    time_elapsed         | 284        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.47400394 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.278     |
# |    explained_variance   | 0.672      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0641    |
# |    n_updates            | 10190      |
# |    policy_gradient_loss | -0.0472    |
# |    value_loss           | 0.0486     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.03e+04   |
# |    ep_rew_mean          | -7.61      |
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 43         |
# |    time_elapsed         | 291        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.19574395 |
# |    clip_fraction        | 0.319      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.325     |
# |    explained_variance   | -5.99      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0627    |
# |    n_updates            | 10200      |
# |    policy_gradient_loss | 0.00231    |
# |    value_loss           | 0.00282    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+04   |
# |    ep_rew_mean          | -7.79      |
# | time/                   |            |
# |    fps                  | 301        |
# |    iterations           | 44         |
# |    time_elapsed         | 299        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.24780874 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.44      |
# |    explained_variance   | 0.425      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0647    |
# |    n_updates            | 10210      |
# |    policy_gradient_loss | -0.0482    |
# |    value_loss           | 0.0296     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+04   |
# |    ep_rew_mean          | -7.66      |
# | time/                   |            |
# |    fps                  | 300        |
# |    iterations           | 45         |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.34000704 |
# |    clip_fraction        | 0.4        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.515     |
# |    explained_variance   | 0.591      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0702    |
# |    n_updates            | 10220      |
# |    policy_gradient_loss | -0.056     |
# |    value_loss           | 0.0578     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+04   |
# |    ep_rew_mean          | -7.73      |
# | time/                   |            |
# |    fps                  | 300        |
# |    iterations           | 46         |
# |    time_elapsed         | 313        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.39510804 |
# |    clip_fraction        | 0.448      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.522     |
# |    explained_variance   | 0.77       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0813    |
# |    n_updates            | 10230      |
# |    policy_gradient_loss | -0.0758    |
# |    value_loss           | 0.057      |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.05e+04  |
# |    ep_rew_mean          | -7.87     |
# | time/                   |           |
# |    fps                  | 299       |
# |    iterations           | 47        |
# |    time_elapsed         | 321       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.3878991 |
# |    clip_fraction        | 0.403     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.45     |
# |    explained_variance   | 0.769     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0889   |
# |    n_updates            | 10240     |
# |    policy_gradient_loss | -0.0685   |
# |    value_loss           | 0.0698    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.05e+04  |
# |    ep_rew_mean          | -7.89     |
# | time/                   |           |
# |    fps                  | 299       |
# |    iterations           | 48        |
# |    time_elapsed         | 328       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.3861032 |
# |    clip_fraction        | 0.379     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.435    |
# |    explained_variance   | 0.813     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0645   |
# |    n_updates            | 10250     |
# |    policy_gradient_loss | -0.0669   |
# |    value_loss           | 0.0683    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.06e+04   |
# |    ep_rew_mean          | -7.77      |
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 49         |
# |    time_elapsed         | 335        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.34609437 |
# |    clip_fraction        | 0.348      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.359     |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0716    |
# |    n_updates            | 10260      |
# |    policy_gradient_loss | -0.0576    |
# |    value_loss           | 0.0691     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+04   |
# |    ep_rew_mean          | -8.03      |
# | time/                   |            |
# |    fps                  | 298        |
# |    iterations           | 50         |
# |    time_elapsed         | 343        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.38248524 |
# |    clip_fraction        | 0.377      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.42      |
# |    explained_variance   | 0.72       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0847    |
# |    n_updates            | 10270      |
# |    policy_gradient_loss | -0.0658    |
# |    value_loss           | 0.114      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+04   |
# |    ep_rew_mean          | -8.08      |
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 51         |
# |    time_elapsed         | 350        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.35907033 |
# |    clip_fraction        | 0.39       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.449     |
# |    explained_variance   | 0.821      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0452    |
# |    n_updates            | 10280      |
# |    policy_gradient_loss | -0.0689    |
# |    value_loss           | 0.116      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+04   |
# |    ep_rew_mean          | -8.35      |
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 52         |
# |    time_elapsed         | 357        |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.48038787 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.396     |
# |    explained_variance   | 0.771      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0848    |
# |    n_updates            | 10290      |
# |    policy_gradient_loss | -0.066     |
# |    value_loss           | 0.113      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+04   |
# |    ep_rew_mean          | -8.63      |
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 53         |
# |    time_elapsed         | 365        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.46322367 |
# |    clip_fraction        | 0.355      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.371     |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0732    |
# |    n_updates            | 10300      |
# |    policy_gradient_loss | -0.0647    |
# |    value_loss           | 0.0975     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+04   |
# |    ep_rew_mean          | -8.58      |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 54         |
# |    time_elapsed         | 372        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.47824004 |
# |    clip_fraction        | 0.365      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.348     |
# |    explained_variance   | 0.777      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0713    |
# |    n_updates            | 10310      |
# |    policy_gradient_loss | -0.0619    |
# |    value_loss           | 0.0933     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+04   |
# |    ep_rew_mean          | -8.42      |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 55         |
# |    time_elapsed         | 379        |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.45113033 |
# |    clip_fraction        | 0.371      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.385     |
# |    explained_variance   | 0.662      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.051     |
# |    n_updates            | 10320      |
# |    policy_gradient_loss | -0.0524    |
# |    value_loss           | 0.054      |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1.04e+04 |
# |    ep_rew_mean          | -8.42    |
# | time/                   |          |
# |    fps                  | 296      |
# |    iterations           | 56       |
# |    time_elapsed         | 387      |
# |    total_timesteps      | 114688   |
# | train/                  |          |
# |    approx_kl            | 0.565446 |
# |    clip_fraction        | 0.387    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.415   |
# |    explained_variance   | 0.699    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0499  |
# |    n_updates            | 10330    |
# |    policy_gradient_loss | -0.0675  |
# |    value_loss           | 0.113    |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.05e+04   |
# |    ep_rew_mean          | -8.99      |
# | time/                   |            |
# |    fps                  | 295        |
# |    iterations           | 57         |
# |    time_elapsed         | 394        |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.68235606 |
# ...
# |    time_elapsed         | 10377     |
# |    total_timesteps      | 2963456   |
# | train/                  |           |
# |    approx_kl            | 0.1309724 |
# |    clip_fraction        | 0.345     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.752    |
# |    explained_variance   | 0.746     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0517   |
# |    n_updates            | 24240     |
# |    policy_gradient_loss | -0.0256   |
# |    value_loss           | 0.0194    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.84e+04   |
# |    ep_rew_mean          | -5.01      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1448       |
# |    time_elapsed         | 10384      |
# |    total_timesteps      | 2965504    |
# | train/                  |            |
# |    approx_kl            | 0.28011882 |
# |    clip_fraction        | 0.35       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.542     |
# |    explained_variance   | 0.558      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0238    |
# |    n_updates            | 24250      |
# |    policy_gradient_loss | -0.0624    |
# |    value_loss           | 0.125      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.83e+04   |
# |    ep_rew_mean          | -5.16      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1449       |
# |    time_elapsed         | 10391      |
# |    total_timesteps      | 2967552    |
# | train/                  |            |
# |    approx_kl            | 0.23982069 |
# |    clip_fraction        | 0.308      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.415     |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0752    |
# |    n_updates            | 24260      |
# |    policy_gradient_loss | -0.0502    |
# |    value_loss           | 0.0758     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.82e+04  |
# |    ep_rew_mean          | -5.46     |
# | time/                   |           |
# |    fps                  | 285       |
# |    iterations           | 1450      |
# |    time_elapsed         | 10399     |
# |    total_timesteps      | 2969600   |
# | train/                  |           |
# |    approx_kl            | 0.2674139 |
# |    clip_fraction        | 0.318     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.441    |
# |    explained_variance   | 0.744     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0263   |
# |    n_updates            | 24270     |
# |    policy_gradient_loss | -0.0532   |
# |    value_loss           | 0.0875    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+04   |
# |    ep_rew_mean          | -5.64      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1451       |
# |    time_elapsed         | 10406      |
# |    total_timesteps      | 2971648    |
# | train/                  |            |
# |    approx_kl            | 0.26433742 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.481     |
# |    explained_variance   | 0.692      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0694    |
# |    n_updates            | 24280      |
# |    policy_gradient_loss | -0.0623    |
# |    value_loss           | 0.0942     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.72e+04  |
# |    ep_rew_mean          | -5.49     |
# | time/                   |           |
# |    fps                  | 285       |
# |    iterations           | 1452      |
# |    time_elapsed         | 10413     |
# |    total_timesteps      | 2973696   |
# | train/                  |           |
# |    approx_kl            | 0.2135404 |
# |    clip_fraction        | 0.311     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.42     |
# |    explained_variance   | 0.775     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0581   |
# |    n_updates            | 24290     |
# |    policy_gradient_loss | -0.0518   |
# |    value_loss           | 0.0684    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+04   |
# |    ep_rew_mean          | -5.6       |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1453       |
# |    time_elapsed         | 10420      |
# |    total_timesteps      | 2975744    |
# | train/                  |            |
# |    approx_kl            | 0.40217957 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.419     |
# |    explained_variance   | 0.751      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0617    |
# |    n_updates            | 24300      |
# |    policy_gradient_loss | -0.0571    |
# |    value_loss           | 0.103      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+04   |
# |    ep_rew_mean          | -5.65      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1454       |
# |    time_elapsed         | 10428      |
# |    total_timesteps      | 2977792    |
# | train/                  |            |
# |    approx_kl            | 0.29153466 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.388     |
# |    explained_variance   | 0.771      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0534    |
# |    n_updates            | 24310      |
# |    policy_gradient_loss | -0.0529    |
# |    value_loss           | 0.0695     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+04   |
# |    ep_rew_mean          | -5.65      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1455       |
# |    time_elapsed         | 10435      |
# |    total_timesteps      | 2979840    |
# | train/                  |            |
# |    approx_kl            | 0.24019015 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.361     |
# |    explained_variance   | 0.738      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0493    |
# |    n_updates            | 24320      |
# |    policy_gradient_loss | -0.0461    |
# |    value_loss           | 0.0639     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+04   |
# |    ep_rew_mean          | -5.65      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1456       |
# |    time_elapsed         | 10442      |
# |    total_timesteps      | 2981888    |
# | train/                  |            |
# |    approx_kl            | 0.21649289 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.471     |
# |    explained_variance   | -11.6      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0609    |
# |    n_updates            | 24330      |
# |    policy_gradient_loss | -0.0163    |
# |    value_loss           | 0.00236    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.68e+04   |
# |    ep_rew_mean          | -5.56      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1457       |
# |    time_elapsed         | 10450      |
# |    total_timesteps      | 2983936    |
# | train/                  |            |
# |    approx_kl            | 0.15233567 |
# |    clip_fraction        | 0.331      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.548     |
# |    explained_variance   | -12.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0384    |
# |    n_updates            | 24340      |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 0.00198    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.65e+04   |
# |    ep_rew_mean          | -5.43      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1458       |
# |    time_elapsed         | 10457      |
# |    total_timesteps      | 2985984    |
# | train/                  |            |
# |    approx_kl            | 0.23204103 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.458     |
# |    explained_variance   | 0.702      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0328    |
# |    n_updates            | 24350      |
# |    policy_gradient_loss | -0.0593    |
# |    value_loss           | 0.09       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.66e+04   |
# |    ep_rew_mean          | -5.45      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1459       |
# |    time_elapsed         | 10464      |
# |    total_timesteps      | 2988032    |
# | train/                  |            |
# |    approx_kl            | 0.25439477 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.436     |
# |    explained_variance   | 0.744      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.071     |
# |    n_updates            | 24360      |
# |    policy_gradient_loss | -0.0558    |
# |    value_loss           | 0.0785     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.66e+04  |
# |    ep_rew_mean          | -5.45     |
# | time/                   |           |
# |    fps                  | 285       |
# |    iterations           | 1460      |
# |    time_elapsed         | 10472     |
# |    total_timesteps      | 2990080   |
# | train/                  |           |
# |    approx_kl            | 0.1673263 |
# |    clip_fraction        | 0.303     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.512    |
# |    explained_variance   | 0.756     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0583   |
# |    n_updates            | 24370     |
# |    policy_gradient_loss | -0.0496   |
# |    value_loss           | 0.0416    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.7e+04     |
# |    ep_rew_mean          | -5.44       |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 1461        |
# |    time_elapsed         | 10479       |
# |    total_timesteps      | 2992128     |
# | train/                  |             |
# |    approx_kl            | 0.112780884 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | -13.7       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0431     |
# |    n_updates            | 24380       |
# |    policy_gradient_loss | 0.00387     |
# |    value_loss           | 0.00277     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+04   |
# |    ep_rew_mean          | -5.41      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1462       |
# |    time_elapsed         | 10486      |
# |    total_timesteps      | 2994176    |
# | train/                  |            |
# |    approx_kl            | 0.16876073 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.524     |
# |    explained_variance   | 0.83       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0667    |
# |    n_updates            | 24390      |
# |    policy_gradient_loss | -0.0463    |
# |    value_loss           | 0.0348     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+04   |
# |    ep_rew_mean          | -5.45      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1463       |
# |    time_elapsed         | 10494      |
# |    total_timesteps      | 2996224    |
# | train/                  |            |
# |    approx_kl            | 0.24991748 |
# |    clip_fraction        | 0.328      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.556     |
# |    explained_variance   | 0.712      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0946    |
# |    n_updates            | 24400      |
# |    policy_gradient_loss | -0.0598    |
# |    value_loss           | 0.0875     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.72e+04  |
# |    ep_rew_mean          | -5.46     |
# | time/                   |           |
# |    fps                  | 285       |
# |    iterations           | 1464      |
# |    time_elapsed         | 10501     |
# |    total_timesteps      | 2998272   |
# | train/                  |           |
# |    approx_kl            | 0.3206787 |
# |    clip_fraction        | 0.329     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.454    |
# |    explained_variance   | 0.791     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0812   |
# |    n_updates            | 24410     |
# |    policy_gradient_loss | -0.0592   |
# |    value_loss           | 0.0892    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.71e+04   |
# |    ep_rew_mean          | -5.49      |
# | time/                   |            |
# |    fps                  | 285        |
# |    iterations           | 1465       |
# |    time_elapsed         | 10509      |
# |    total_timesteps      | 3000320    |
# | train/                  |            |
# |    approx_kl            | 0.23177686 |
# |    clip_fraction        | 0.322      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.454     |
# |    explained_variance   | 0.774      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0622    |
# |    n_updates            | 24420      |
# |    policy_gradient_loss | -0.0596    |
# |    value_loss           | 0.105      |
# ----------------------------------------

# %%
play()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 play()
#
# Cell In[1], line 40, in play()
#      38 while True:
#      39     action, _states = model.predict(obs, deterministic=False)
# ---> 40     obs, rewards, dones, info = env.step(action)
#      41     env.render("human")
#      42     time.sleep(0.01)
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:222, in VecEnv.step(self, actions)
#     215 """
#     216 Step the environments with the given action
#     217
#     218 :param actions: the action
#     219 :return: observation, reward, done, information
#     220 """
#     221 self.step_async(actions)
# --> 222 return self.step_wait()
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/vec_frame_stack.py:39, in VecFrameStack.step_wait(self)
#      31 def step_wait(
#      32     self,
#      33 ) -> tuple[
#    (...)     37     list[dict[str, Any]],
#      38 ]:
# ---> 39     observations, rewards, dones, infos = self.venv.step_wait()
#      40     observations, infos = self.stacked_obs.update(observations, dones, infos)  # type: ignore[arg-type]
#      41     return observations, rewards, dones, infos
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:59, in DummyVecEnv.step_wait(self)
#      56 def step_wait(self) -> VecEnvStepReturn:
#      57     # Avoid circular imports
#      58     for env_idx in range(self.num_envs):
# ---> 59         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(  # type: ignore[assignment]
#      60             self.actions[env_idx]
#      61         )
#      62         # convert to SB3 VecEnv api
#      63         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/Documents/Courses/Spring-2025/Final/repo/Atari/wrapper/wrapper.py:40, in PongWrapper.step(self, action)
#      38 # Send (stack_size - 1) NOOP actions first
#      39 for _ in range(self.buffer_stack_size - 1):
# ---> 40     obs, reward, terminated, truncated, info = self.env.step(NO_OP)
#      41     total_reward += reward
#      42     if terminated or truncated:
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/gymnasium/core.py:595, in RewardWrapper.step(self, action)
#     591 def step(
#     592     self, action: ActType
#     593 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     594     """Modifies the :attr:`env` :meth:`step` reward using :meth:`self.reward`."""
# --> 595     observation, reward, terminated, truncated, info = self.env.step(action)
#     596     return observation, self.reward(reward), terminated, truncated, info
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/gymnasium/core.py:560, in ObservationWrapper.step(self, action)
#     556 def step(
#     557     self, action: ActType
#     558 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     559     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 560     observation, reward, terminated, truncated, info = self.env.step(action)
#     561     return self.observation(observation), reward, terminated, truncated, info
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/stable_baselines3/common/atari_wrappers.py:112, in EpisodicLifeEnv.step(self, action)
#     111 def step(self, action: int) -> AtariStepReturn:
# --> 112     obs, reward, terminated, truncated, info = self.env.step(action)
#     113     self.was_real_done = terminated or truncated
#     114     # check current lives, make loss of life terminal,
#     115     # then update lives to handle bonus lives
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/stable_baselines3/common/atari_wrappers.py:178, in MaxAndSkipEnv.step(self, action)
#     176 terminated = truncated = False
#     177 for i in range(self._skip):
# --> 178     obs, reward, terminated, truncated, info = self.env.step(action)
#     179     done = terminated or truncated
#     180     if i == self._skip - 2:
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/Documents/Courses/Spring-2025/Final/venv/lib/python3.12/site-packages/ale_py/env.py:311, in AtariEnv.step(self, action)
#     309 reward = 0.0
#     310 for _ in range(frameskip):
# --> 311     reward += self.ale.act(action_idx, strength)
#     313 is_terminal = self.ale.game_over(with_truncation=False)
#     314 is_truncated = self.ale.game_truncated()
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3 import A2C

import ale_py

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
vec_env = make_atari_env("PongNoFrameskip-v4", n_envs=4, seed=0)
# Frame-stacking with 4 frames
vec_env = VecFrameStack(vec_env, n_stack=4)

model = A2C("CnnPolicy", vec_env, verbose=1)
model.learn(total_timesteps=1)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
obs = vec_env.reset()
while True:
    action, _states = model.predict(obs, deterministic=False)
    obs, rewards, done, info = vec_env.step(action)
    vec_env.render("human")
    time.sleep(0.05)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 6
#       4 obs, rewards, dones, info = vec_env.step(action)
#       5 vec_env.render("human")
# ----> 6 time.sleep(0.05)
#
# KeyboardInterrupt:
